# %% [markdown]
# Homework 1
#
# 1.	Install Python (if you don’t have it already), and install NLTK.
#
# 2.	Follow the instructions in chapter 1 of Bird-Klein for implementing a “lexical diversity” scoring routine.
#
# 3.	Go to http://www.gutenberg.org/wiki/Children%27s_Instructional_Books_(Bookshelf), and obtain three texts (of different grade levels) from the “Graded Readers” section. Report the lexical diversity score of each. Explain whether the result was surprising.
#
# 4.	Also compare the vocabulary size of the same three texts. Explain whether the result was surprising.
#
# 5.	Write a paragraph arguing whether vocabulary size and lexical diversity in combination could be a better measure of text difficulty (or reading level) than either measure is by itself.

# %% [markdown]
# 1.	Install Python (if you don’t have it already), and install NLTK.

# %%
import nltk
import pandas as pd

# %%
column_names = ["name", "lexical_diversity", "vocab_count"]

dftext = pd.DataFrame(columns = column_names)

# %% [markdown]
# nltk.download('popular')

# %% [markdown]
# nltk.download('nps_chat')
# nltk.download('webtext')

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# Lexical diversity is one aspect of 'lexical richness' and refers to the ratio of different unique word stems (types) to the total number of words (tokens). The term is used in applied linguistics and is quantitatively calculated using numerous different measures including Text-Type Ratio (TTR), vocd,[1] and the measure of textual lexical diversity.
#
# A common problem with lexical diversity measures, especially TTR, is that text samples containing large number of tokens give lower values for TTR since it is often necessary for the writer or speaker to re-use several function words. One consequence of this is that lexical diversity is better used for comparing texts of equal length.[3] Newer measures of lexical diversity attempt to account for sensitivity to text length.

# %% [markdown]
# 2.	Follow the instructions in chapter 1 of Bird-Klein for implementing a “lexical diversity” scoring routine.

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
def vocab_size(text):
    return len(set(text))

# %%
def percentage(count, total):
    return 100 * count / total

# %%
text7
# Out:
# <Text: Wall Street Journal>

# %%
lexical_diversity(text7)
# Out:
# 0.12324685128531129

# %%
vocab_size(text7)
# Out:
# 12408

# %% [markdown]
# 3.	Go to http://www.gutenberg.org/wiki/Children%27s_Instructional_Books_(Bookshelf), and obtain three texts (of different grade levels) from the “Graded Readers” section. Report the lexical diversity score of each. Explain whether the result was surprising.

# %% [markdown]
# 1st Level

# %%
f = open(r'14640-8.txt', "r")

# %%
book1 = ""
for x in f:
    book1 = book1 + x

# %%
book1
# Out:
# 'Edition, by William Holmes McGuffey\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org\n\n\nTitle: McGuffey\'s First Eclectic Reader, Revised Edition\n\nAuthor: William Holmes McGuffey\n\nRelease Date: June 29, 2005 [EBook #14640]\n\nLanguage: English\n\nCharacter set encoding: ISO-8859-1\n\n*** START OF THIS PROJECT GUTENBERG EBOOK MCGUFFEY\'S FIRST READER ***\n\n\n\n\nProduced by Don Kostuch\n\n\n\n\n\n[Transcriber\'s Notes:\n\nWelcome to the schoolroom of 1900. The moral tone is plain. "She is kind\nto the old blind man."\n\nThe exercises are still suitable, and perhaps more helpful than some\ncontemporary alternatives. Much is left to the teacher. Explanations given\nin the text are enough to get started teaching a child to read and write.\nCounting in Roman numerals is included
# ...

# %%
lexical_diversity(book1)
# Out:
# 0.0013813725968179675

# %%
vocab_size(book1)
# Out:
# 85

# %%
listt = []
dictt = {"name" : "McGuffey\'s First Eclectic Reader, Revised Edition", "lexical_diversity" : lexical_diversity(book1), "vocab_count" : vocab_size(book1)}
listt.append(dictt)

# %% [markdown]
# Fifth Level

# %%
f = open(r'pg15040.txt', "r")

# %%
book2 = ""
for x in f:
    book2 = book2 + x

# %%
book2
# Out:
# 'ï»¿The Project Gutenberg EBook of McGuffey\'s Fifth Eclectic Reader\nby William Holmes McGuffey\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org\n\n\nTitle: McGuffey\'s Fifth Eclectic Reader\n\nAuthor: William Holmes McGuffey\n\nRelease Date: February 14, 2005 [EBook #15040]\n\nLanguage: English\n\n\n*** START OF THIS PROJECT GUTENBERG EBOOK MCGUFFEY\'S FIFTH ECLECTIC READER ***\n\n\n\n\nProduced by Don Kostuch\n\n\n\n\n\nECLECTIC EDUCATIONAL SERIES.\n\n\nMcGUFFEY\'S\n\nFIFTH ECLECTIC READER.\n\nREVISED EDITION.\n\nMcGuffey Editions and Colophon are Trademarks of\n\nJohn Wiley & Sons, Inc.\nNew York-Chichester-Weinheim-Brisbane-Singapore-Toronto\n\n\nCopyright, 1879, by VAN ANTWERP, BRAGG & CO.\nCopyright, 1896, by AMERICAN BOOK COMPANY.\nCopyright, 1907 and 1920, by H. H. VAIL.\n
# ...

# %%
lexical_diversity(book2)
# Out:
# 0.00015035460034395728

# %%
vocab_size(book2)
# Out:
# 89

# %%
dictt = {"name" : "MccGuffey\'s Fifth Eclectic Reader", "lexical_diversity" : lexical_diversity(book2), "vocab_count" : vocab_size(book2)}
listt.append(dictt)

# %% [markdown]
# Sixth Level

# %%
f = open(r'pg16751.txt', "r")

# %%
book3 = ""
for x in f:
    book3 = book3 + x

# %%
book3
# Out:
# 'ï»¿The Project Gutenberg EBook of McGuffey\'s Sixth Eclectic Reader\nby William Holmes McGuffey\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org\n\n\nTitle: McGuffey\'s Sixth Eclectic Reader\n\nAuthor: William Holmes McGuffey\n\nRelease Date: September 26, 2005 [EBook #16751]\n\nLanguage: English\n\n\n*** START OF THIS PROJECT GUTENBERG EBOOK MCGUFFEY\'S SIXTH ECLECTIC READER ***\n\n\n\n\nProduced by Don Kostuch\n\n\n\n\n\n[Transcriber\'s Notes:\nWelcome to the schoolroom of 1900. The moral tone is plain.\n"She is kind to the old blind man."\n\nThe exercises are still suitable, and perhaps more helpful than some\ncontemporary alternatives. Much is left to the teacher. Explanations given\nin the text are enough to get started teaching a child to read and write.\nCounting in Roman n
# ...

# %%
lexical_diversity(book3)
# Out:
# 0.00010922979643206938

# %%
vocab_size(book3)
# Out:
# 90

# %%
dictt = {"name" : "MccGuffey\'s Sixth Eclectic Reader", "lexical_diversity" : lexical_diversity(book3), "vocab_count" : vocab_size(book3)}
listt.append(dictt)

# %%
listt
# Out:
# [{'name': "McGuffey's First Eclectic Reader, Revised Edition",
#   'lexical_diversity': 0.0013813725968179675,
#   'vocab_count': 85},
#  {'name': "MccGuffey's Fifth Eclectic Reader",
#   'lexical_diversity': 0.00015035460034395728,
#   'vocab_count': 89},
#  {'name': "MccGuffey's Sixth Eclectic Reader",
#   'lexical_diversity': 0.00010922979643206938,
#   'vocab_count': 90}]

# %%
dftext = pd.DataFrame(listt)
dftext
# Out:
#                                                 name  lexical_diversity  \
# 0  McGuffey's First Eclectic Reader, Revised Edition           0.001381
# 1                  MccGuffey's Fifth Eclectic Reader           0.000150
# 2                  MccGuffey's Sixth Eclectic Reader           0.000109
#
#    vocab_count
# 0           85
# 1           89
# 2           90

# %% [markdown]
# Explain whether the result was surprising.
# This result is actually surprising to me as I would have expected the diversity to increase since I had chosen books titles from 1 to 6 levels. I thought the sixth level would be the most diverse. My thought was that it would for a sixth grader and therefore more complex than the first reader.

# %% [markdown]
# 4. Also compare the vocabulary size of the same three texts. Explain whether the result was surprising.
#
#  The vocabulary size increases from first through the sixth reader. This seems to make sense as it seems to say that a larger variety of words are used as we progress from the first to the sixth addition.

# %% [markdown]
# 5. Write a paragraph arguing whether vocabulary size and lexical diversity in combination could be a better measure of text difficulty (or reading level) than either measure is by itself.
#
# The combination of diversity and vocabulary count could be a better measure than either by themself. The vocabulary count could be increased by having a larger text. The diversity could be increased by having a shorter text. So knowing both scores and the length of the text in combination would help a person studying the text to know which score is most useful in the scenario they are examining.
